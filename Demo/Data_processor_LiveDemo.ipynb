# %% [markdown]
# # Live Data Processor
# Process the data by yourself. Go to **Runtime and select execute all**, or press: **CRTL** + **F9**.
#
# After the machine is done, click on the **document symbol** on the left. Your search results are now available as csv's.
#
#
# Hendrik Snijder March 2023
#
#
# **P.S.** If the CSV's are not available, the program is not ready yet or you have to click again on the document symbol.

# %%
Ontology_Path = ["https://raw.githubusercontent.com/SanliFaez/FAIR-Battery-knowledgebase/main/Ontology/FAIR-Battery-ontology.owl"]

#Fill in https link to data.csv in between ''.
RawData_Path = "https://raw.githubusercontent.com/SanliFaez/FAIR-Battery-knowledgebase/main/Datamanagement/Data_Raw.csv"

# %%
# !pip install request
# Data
import numpy as np 
import pandas as pd 
import time 
import csv
from collections import Counter 
import matplotlib.pyplot as plt  
# Ontology
# !pip install owlready2 
from owlready2 import * 
import re  # To separate words based on capital letters in onto classes & to split search queries
import sys
print("Import done")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement request (from versions: none)
# ERROR: No matching distribution found for request
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: owlready2 in /usr/local/lib/python3.9/dist-packages (0.40)
# Import done

# %%
import requests
# Save datagenerators as file to colab working directory
# If you are using GitHub, make sure you get the "Raw" version of the code
url = 'https://raw.githubusercontent.com/SanliFaez/FAIR-Battery-knowledgebase/main/Demo/functions.py'
r = requests.get(url)

# make sure your filename is the same as how you want to import 
with open('functions.py', 'w') as f:
    f.write(r.text)

# now we can import
import functions

# %%
""" Extra input for the function"""
# The ImportAndMineData function is used in several notebooks, therefore we need to fill in the variables in this block.
# Enter your search query here in between "". 
# Separate keywords by '| AND |' and '| OR |' 
# Be aware of capital letters
# Never begin or end query with '|'
# Choose free search ('y') if you want to search outside the ontology

QUERY= ""
free_search = 'y' # y/n

  # 'y': to search broader then ontology
  # 'n': to sarch only on ontological terms
  #Fill in https link to ontology class in between brackets and ''. only .owl are alowed

# %%
# Process Data and search for query words
df = functions.ImportAndMineData(Ontology_Path, RawData_Path, QUERY, 'y')
df.to_csv("Processed_Data.CSV")
# Out:
# ...Loading query...
# ..Query loaded...Start searching...
# Your imported ontology with 33 classes is ready to use
# Your 5644 articles are searched on 33 ontology classes in 0.6024589538574219 seconds.
# type df_processed to view data frame
# data colected

# %%
df
# Out:
#            Key       Item Type  Publication Year  \
# 0     XZFCQW4R  journalArticle            2022.0
# 1     ZBB8CWXM         webpage               NaN
# 2     BU9MHXRQ  journalArticle            2011.0
# 3     FL85BE79         webpage               NaN
# 4     Z8L8S4NE         webpage               NaN
# ...        ...             ...               ...
# 5639  UGGEVWRD     bookSection            1986.0
# 5640  W555XWQS  journalArticle            1987.0
# 5641  PAGLZNBF  journalArticle            1986.0
# 5642  DKB5XV2Q  journalArticle            1985.0
# 5643  KULCIMZT  journalArticle            1994.0
#
#                                                  Author  \
# 0                     Eder, Konstantin; Sahlmann, Hanno
# 1                                                   NaN
# 2     Weber, Adam Z.; Mench, Matthew M.; Meyers, Jer...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5639         Ohya, H.; Emori, K.; Ohto, T.; Negishi, Y.
# 5640                                      Homma, Takuya
# 5641                       Takahashi, S.; Hiramatsu, T.
# 5642                       Sum, E.; Skyllas-Kazacos, M.
# 5643                  Ogawa, Hiroyasu; Shimazaki, Kenji
#
#                                                   Title  \
# 0     Towards black hole entropy in chiral loop quan...
# 1     Redox flow batteries: Status and perspective t...
# 2                        Redox flow batteries: a review
# 3     The soluble lead flow battery: Image-based mod...
# 4     Techno-economic assessment of novel vanadium r...
# ...                                                 ...
# 5639     Ion-selective Membranes for Redox-flow Battery
# 5640  Theoretical studies on transient characteristi...
# 5641  Overview of rechargeable battery testing in Japan
# 5642  A study of the V(II)/V(III) redox couple for r...
# 5643  Studies on the Improvement of Productivity of ...
#
#                              Publication Title  \
# 0     arXiv:2204.01661 [gr-qc, physics:hep-th]
# 1                                          NaN
# 2          Journal of Applied Electrochemistry
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 5639          Membranes and Membrane Processes
# 5640     IEEJ Transactions on Power and Energy
# 5641                  Journal of Power Sources
# 5642                  Journal of Power Sources
# 5643                      NIPPON KAGAKU KAISHI
#
#                                      ISBN                  ISSN  \
# 0                                     NaN                   NaN
# 1                                     NaN                   NaN
# 2                                     NaN  0021-891X, 1572-8838
# 3                                     NaN                   NaN
# 4                                     NaN                   NaN
# ...                                   ...                   ...
# 5639  978-1-4899-2021-8 978-1-4899-2019-5                   NaN
# 5640                                  NaN  0385-4213, 1348-8147
# 5641                                  NaN              03787753
# 5642                                  NaN              03787753
# 5643                                  NaN  2185-0925, 0369-4577
#
#                                DOI  \
# 0                              NaN
# 1                              NaN
# 2        10.1007/s10800-011-0348-2
# 3                              NaN
# 4                              NaN
# ...                            ...
# 5639                           NaN
# 5640   10.1541/ieejpes1972.107.449
# 5641  10.1016/0378-7753(86)80012-X
# 5642  10.1016/0378-7753(85)80071-9
# 5643    10.1246/nikkashi.1994.1112
#
#                                                     Url  ...  \
# 0                       http://arxiv.org/abs/2204.01661  ...
# 1     https://reader.elsevier.com/reader/sd/pii/S037...  ...
# 2     http://link.springer.com/10.1007/s10800-011-03...  ...
# 3     https://reader.elsevier.com/reader/sd/pii/S235...  ...
# 4     https://reader.elsevier.com/reader/sd/pii/S037...  ...
# ...                                                 ...  ...
# 5639  http://link.springer.com/10.1007/978-1-4899-20...  ...
# 5640  http://www.jstage.jst.go.jp/article/ieejpes197...  ...
# 5641  https://linkinghub.elsevier.com/retrieve/pii/0...  ...
# 5642  https://linkinghub.elsevier.com/retrieve/pii/0...  ...
# 5643  http://joi.jlc.jst.go.jp/JST.Journalarchive/ni...  ...
#
#      Non Aqueous Organometallic Non Aqueous Organometallic Electrolyte  \
# 0                            []                                     []
# 1                            []                                     []
# 2                            []                                     []
# 3                            []                                     []
# 4                            []                                     []
# ...                         ...                                    ...
# 5639                         []                                     []
# 5640                         []                                     []
# 5641                         []                                     []
# 5642                         []                                     []
# 5643                         []                                     []
#
#      Power density Pump Pumpless Redox Potential  Stack Subcomponent leakages  \
# 0               []   []       []              []     []           []       []
# 1               []   []       []              []     []           []       []
# 2               []   []       []              []     []           []       []
# 3               []   []       []              []     []           []       []
# 4               []   []       []              []     []           []       []
# ...            ...  ...      ...             ...    ...          ...      ...
# 5639            []   []       []              []     []           []       []
# 5640            []   []       []              []     []           []       []
# 5641            []   []       []              []     []           []       []
# 5642            []   []       []              []     []           []       []
# 5643            []   []       []              []     []           []       []
#
#          !EMPTY CLASS
# 0     [n, n, n, n, n]
# 1                 [n]
# 2           [n, n, n]
# 3                 [n]
# 4                 [n]
# ...               ...
# 5639              [n]
# 5640              [n]
# 5641              [n]
# 5642              [n]
# 5643              [n]
#
# [5644 rows x 121 columns]
